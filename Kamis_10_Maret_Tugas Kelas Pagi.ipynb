# %% [markdown]
# ## Latihan 4
#
# Coba bikin kesimpulan dari hasil p-value tersebut
#
# p-value = 1.0993 * 10^(-11) < 0.05 artinya: Ho ditolak berarti ada perbedaan yang signifikan untuk kualitas di antar wilayah

# %% [markdown]
# # Latihan tambahan
#
# Misalkan kamu adalah data scientist di gojek. Kamu ingin mengetahui apakah kemacetan mempengaruhi tingkat kepuasan pelanggan. Jadi kamu ingin memebandingkan nilai "bintang" dari customer saat dia order di jam macet dan tidak macet.
# (#hint = data dari customer yang sama)
#
# macet = [2, 3, 5, 4, 5, 4, 4, 3, 4, 3, 4, 5, 4, 5, 4, 3, 4, 3, 3, 5, 4, 3, 4, 3, 4, 3, 4, 4, 5]
#
# tidak_macet = [2, 2, 4, 5, 4, 3, 3, 3, 3, 3, 3, 4, 4, 5, 4, 3, 3, 2, 3, 4, 4, 3, 3, 3, 4, 3, 4, 3, 4]
#
# 1. Buat hipotesisnya
# 2. Lakukan uji asumsi normalitasnya
# 3. Jika datanya normal lakukan uji parametrik, jika tidak berdistribusi normal lakukan uji nonparametrik
# 4. Apa kesimpulan uji hipotesisnya?

# %% [markdown]
# ![tabel%20uji.jpg](attachment:tabel%20uji.jpg)

# %% [markdown]
# -

# %% [markdown]
# # 1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats

# %%
macet = np.array([2, 3, 5, 4, 5, 4, 4, 3, 4, 3, 4, 5, 4, 5, 4, 3, 4, 3, 3, 5, 4, 3, 4, 3, 4, 3, 4, 4, 5])

tidak_macet = np.array([2, 2, 4, 5, 4, 3, 3, 3, 3, 3, 3, 4, 4, 5, 4, 3, 3, 2, 3, 4, 4, 3, 3, 3, 4, 3, 4, 3, 4])

# %% [markdown]
# # 2

# %%
# Histogram
histogram = sns.distplot(macet), sns.distplot(tidak_macet)
print(histrogram)
# Out:
# C:\Users\zikri\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\zikri\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12052/2218082696.py in <module>
#       1 histogram = sns.distplot(macet), sns.distplot(tidak_macet)
# ----> 2 print(histrogram)
#
# NameError: name 'histrogram' is not defined

# %%
# Uji Kolmogorov-Smirnov
z_score_macet = stats.zscore(macet)
z_score_tidak_macet = stats.zscore(tidak_macet)
print('Hasil Uji Kolmogrov-Smirnov terkait data macet adalah : ', stats.kstest(z_score_macet, "norm"))
print()
print('Hasil Uji Kolmogrov-Smirnov terkait data tidak macet adalah :', stats.kstest(z_score_tidak_macet, "norm"))
# Out:
# Hasil Uji Kolmogrov-Smirnov terkait data macet adalah :  KstestResult(statistic=0.2414618941043637, pvalue=0.05668522245349683)
#
# Hasil Uji Kolmogrov-Smirnov terkait data tidak macet adalah : KstestResult(statistic=0.2769460572882385, pvalue=0.018550502658514323)

# %% [markdown]
# # 3

# %% [markdown]
# **Dari hasil pengujian diatas terlihat bahwa data tidak berdistribusi normal, maka kita akan melakukan uji beda non-parametrik wilcoxon, Uji wilcoxon diperlukan karena 2 kelompok data saling berhubungan.**

# %%
a = macet - tidak_macet
stats.wilcoxon(a)
# Out:
# WilcoxonResult(statistic=8.0, pvalue=0.0007891129890156299)

# %% [markdown]
# # 4
# ## Kesimpulan

# %% [markdown]
# Dari semua hasil pengujian, bisa kita simpulkan bahwa Ho ditolak karena P-Value lebih lebih besar dari 0.05.
#
# jadi kemacetan itu berpengaruh dalam menghasilkan nilai 'Rating' yang signifikan dari costumer.
